# %% [markdown]
# The Atomic Simulation Environment (ASE) is a set of tools and Python modules for setting up, manipulating, running, visualizing and analyzing atomistic simulations.
#
# https://wiki.fysik.dtu.dk/ase/

# %%
#Impordime vajalikud teegid
from ase.build import bulk, molecule
from ase.io import write
from gpaw import GPAW
from gpaw.elf import ELF
from gpaw.test import equal
from gpaw.mpi import rank

# %%
#Oluline vaid visualiseerimiseks
from IPython.display import HTML
def atoms_to_html(atoms):
    'Return the html representation the atoms object as string'

    from tempfile import NamedTemporaryFile

    with NamedTemporaryFile('r+', suffix='.html') as ntf:
        atoms.write(ntf.name, format='html')
        ntf.seek(0)
        html = ntf.read()
    return html

# %% [markdown]
# ### Atoms
#
# The Atoms object is a collection of atoms. Here is how to define a N2 molecule by directly specifying the position of two nitrogen atoms:

# %%
from ase import Atoms
d = 1.10
molecule = Atoms('2N', positions=[(0., 0., 0.), (0., 0., d)])

# %%
HTML(atoms_to_html(molecule))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="0.00 0.00 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.71">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 0.00 1.10">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.188 0.314 0.973" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.71">
#       </Sphere>
#      </Shape>
#     </Transform>
#    </Scene>
#   </X3D>
#  </body>
# </html>

# %% [markdown]
# Use a built in method to build a molecule

# %%
from ase.build import molecule
water = molecule('H2O')
water.center(vacuum=3.5)
HTML(atoms_to_html(water))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="3.50 4.26 4.10">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 0.051 0.051" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.66">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 5.03 3.50">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 3.50 3.50">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#    </Scene>
#   </X3D>
#  </body>
# </html>

# %%
#define the calculator
calc = GPAW(h=0.18, xc='PBE', txt='h2o.txt')
water.set_calculator(calc)
water.get_potential_energy()

#wite .cube info about electron localization to a file
elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('h2o.cube', water, data=elf_g)
# Out:
# /usr/lib/python3/dist-packages/gpaw/fd_operators.py:184: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   a_d, residual, rank, s = np.linalg.lstsq(A_md, [1, 1, 1, 0, 0, 0])

# %% [markdown]
# More about electron localization
# https://en.wikipedia.org/wiki/Electron_localization_function

# %% [markdown]
# Defining another molecule

# %%
from ase.build import molecule
sys = molecule('C6H6')
#sys.center(vacuum=3.5)
HTML(atoms_to_html(sys))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="0.00 1.40 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.21 0.70 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.21 -0.70 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 -1.40 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="-1.21 -0.70 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="-1.21 0.70 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 2.48 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.15 1.24 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.15 -1.24 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 -2.48 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="-2.15 -1.24 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="-2.15 1.24 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#    </Scene>
#   </X3D>
#  </body>
# </html>

# %%
calc = GPAW(h=0.18, xc='PBE', txt='c6h6.txt')
sys.set_calculator(calc)
sys.get_potential_energy()

elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('c6h6.cube', sys, data=elf_g)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-7b2cd6da839a> in <module>()
#       1 calc = GPAW(h=0.18, xc='PBE', txt='c6h6.txt')
#       2 sys.set_calculator(calc)
# ----> 3 sys.get_potential_energy()
#       4
#       5 elf = ELF(calc)
#
# ~/.local/lib/python3.6/site-packages/ase/atoms.py in get_potential_energy(self, force_consistent, apply_constraint)
#     682                 self, force_consistent=force_consistent)
#     683         else:
# --> 684             energy = self._calc.get_potential_energy(self)
#     685         if apply_constraint:
#     686             for constraint in self.constraints:
#
# ~/.local/lib/python3.6/site-packages/ase/calculators/calculator.py in get_potential_energy(self, atoms, force_consistent)
#     439
#     440     def get_potential_energy(self, atoms=None, force_consistent=False):
# --> 441         energy = self.get_property('energy', atoms)
#     442         if force_consistent:
#     443             if 'free_energy' not in self.results:
#
# ~/.local/lib/python3.6/site-packages/ase/calculators/calculator.py in get_property(self, name, atoms, allow_calculation)
#     484             if not allow_calculation:
#     485                 return None
# --> 486             self.calculate(atoms, [name], system_changes)
#     487
#     488         if name == 'magmom' and 'magmom' not in self.results:
#
# /usr/lib/python3/dist-packages/gpaw/calculator.py in calculate(self, atoms, properties, system_changes)
#     247                 self.hamiltonian = None
#     248                 self.scf = None
# --> 249                 self.initialize(atoms)
#     250
#     251             self.set_positions(atoms)
#
# /usr/lib/python3/dist-packages/gpaw/calculator.py in initialize(self, atoms, reading)
#     447             raise ValueError(
#     448                 'GPAW requires 3 lattice vectors.  Your system has {0}.'
# --> 449                 .format(number_of_lattice_vectors))
#     450
#     451         pbc_c = atoms.get_pbc()
#
# ValueError: GPAW requires 3 lattice vectors.  Your system has 0.

# %% [markdown]
# Defining a graphene sheet

# %%
from ase.build.surface import hcp0001
from math import sqrt

a = 2.461
c = 6.708
sys = hcp0001('C', a=a/sqrt(3), c=c, vacuum=c/4., size=(4,4,1), orthogonal=True)
HTML(atoms_to_html(sys))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="0.00 0.00 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.42 0.00 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.84 0.00 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.26 0.00 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.71 1.23 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.13 1.23 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.55 1.23 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.97 1.23 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 2.46 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.42 2.46 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.84 2.46 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.26 2.46 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.71 3.69 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.13 3.69 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.55 3.69 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.97 3.69 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#    </Scene>
#   </X3D>
#  </body>
# </html>

# %%
calc = GPAW(h=0.18, xc='PBE', txt='gr.txt')
sys.set_calculator(calc)
sys.get_potential_energy()

elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('gr.cube', sys, data=elf_g)

# %% [markdown]
# Defining a diamond

# %%
from ase.build import bulk
sys = bulk('C', 'diamond', a=3.57, cubic=True)
sys *= (2, 2, 2)
HTML(atoms_to_html(sys))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="0.00 0.00 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.89 0.89 0.89">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 1.78 1.78">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.89 2.68 2.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.78 0.00 1.78">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.68 0.89 2.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.78 1.78 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.68 2.68 0.89">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 0.00 3.57">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.89 0.89 4.46">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 1.78 5.35">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.89 2.68 6.25">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.78 0.00 5.35">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.68 0.89 6.25">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.78 1.78 3.57">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.68 2.68 4.46">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 3.57 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.89 4.46 0.89">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 5.35 1.78">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.89 6.25 2.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.78 3.57 1.78">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.68 4.46 2.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.78 5.35 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.68 6.25 0.89">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 3.57 3.57">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.89 4.46 4.46">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 5.35 5.35">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.89 6.25 6.25">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.78 3.57 5.35">

# %%
calc = GPAW(h=0.18, xc='PBE', txt='c.txt')
sys.set_calculator(calc)
sys.get_potential_energy()

elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('c.cube', sys, data=elf_g)
# Out:
# /usr/lib/python3/dist-packages/gpaw/fd_operators.py:184: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   a_d, residual, rank, s = np.linalg.lstsq(A_md, [1, 1, 1, 0, 0, 0])

# %% [markdown]
# Defining a bulk metal

# %%
from ase.build import bulk

sys = bulk("Li", "bcc", a=3.51, cubic=True)
sys *= (2, 2, 2)
HTML(atoms_to_html(sys))

# %%
calc = GPAW(h=0.18, xc='PBE', txt='li.txt')
sys.set_calculator(calc)
sys.get_potential_energy()

elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('li.cube', sys, data=elf_g)
