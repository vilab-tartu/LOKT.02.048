# %% [markdown]
# The Atomic Simulation Environment (ASE) is a set of tools and Python modules for setting up, manipulating, running, visualizing and analyzing atomistic simulations.
#
# https://wiki.fysik.dtu.dk/ase/

# %%
#Impordime vajalikud teegid
from ase.build import bulk, molecule
from ase.io import write
from gpaw import GPAW
from gpaw.elf import ELF
from gpaw.test import equal
from gpaw.mpi import rank

# %%
#Oluline vaid visualiseerimiseks
from IPython.display import HTML
def atoms_to_html(atoms):
    'Return the html representation the atoms object as string'

    from tempfile import NamedTemporaryFile

    with NamedTemporaryFile('r+', suffix='.html') as ntf:
        atoms.write(ntf.name, format='html')
        ntf.seek(0)
        html = ntf.read()
    return html

# %% [markdown]
# ### Atoms
#
# The Atoms object is a collection of atoms. Here is how to define a N2 molecule by directly specifying the position of two nitrogen atoms:

# %%
from ase import Atoms
d = 1.10
molecule = Atoms('2N', positions=[(0., 0., 0.), (0., 0., d)])

# %%
#HTML(atoms_to_html(molecule))

# %% [markdown]
# Use a built in method to build a molecule

# %%
from ase.build import molecule
water = molecule('H2O')
#water.center(vacuum=3.5)
#HTML(atoms_to_html(water))

# %%
#define the calculator
calc = GPAW(h=0.18, xc='PBE', txt='h2o.txt')
water.set_calculator(calc)
water.get_potential_energy()

#wite .cube info about electron localization to a file
elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('h2o.cube', water, data=elf_g)

# %% [markdown]
# More about electron localization
# https://en.wikipedia.org/wiki/Electron_localization_function

# %% [markdown]
# Defining another molecule

# %%
from ase.build import molecule
sys = molecule('C6H6')
#sys.center(vacuum=3.5)
HTML(atoms_to_html(sys))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="0.00 1.40 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.21 0.70 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.21 -0.70 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 -1.40 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="-1.21 -0.70 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="-1.21 0.70 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 2.48 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.15 1.24 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.15 -1.24 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 -2.48 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="-2.15 -1.24 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="-2.15 1.24 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.31">
#       </Sphere>
#      </Shape>
#     </Transform>
#    </Scene>
#   </X3D>
#  </body>
# </html>

# %%
calc = GPAW(h=0.18, xc='PBE', txt='c6h6.txt')
sys.set_calculator(calc)
sys.get_potential_energy()

elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('c6h6.cube', sys, data=elf_g)

# %% [markdown]
# Defining a graphene sheet

# %%
from ase.build.surface import hcp0001
from math import sqrt

a = 2.461
c = 6.708
sys = hcp0001('C', a=a/sqrt(3), c=c, vacuum=c/4., size=(4,4,1), orthogonal=True)

HTML(atoms_to_html(sys))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="0.00 0.00 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.42 0.00 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.84 0.00 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.26 0.00 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.71 1.23 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.13 1.23 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.55 1.23 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.97 1.23 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 2.46 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.42 2.46 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.84 2.46 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.26 2.46 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.71 3.69 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="2.13 3.69 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.55 3.69 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.97 3.69 1.68">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#    </Scene>
#   </X3D>
#  </body>
# </html>

# %%
calc = GPAW(h=0.18, xc='PBE', txt='gr.txt')
sys.set_calculator(calc)
sys.get_potential_energy()

elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('gr.cube', sys, data=elf_g)

# %% [markdown]
# Defining a diamond

# %%
from ase.build import bulk
sys = bulk('C', 'diamond', a=3.57, cubic=True)
sys.center(vacuum=3.5)
sys *= (2,2,2)
HTML(atoms_to_html(sys))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="3.50 3.50 3.50">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.39 4.39 4.39">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 5.29 5.29">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.39 6.18 6.18">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="5.29 3.50 5.29">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="6.18 4.39 6.18">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="5.29 5.29 3.50">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="6.18 6.18 4.39">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 3.50 13.18">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.39 4.39 14.07">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 5.29 14.96">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.39 6.18 15.86">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="5.29 3.50 14.96">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="6.18 4.39 15.86">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="5.29 5.29 13.18">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="6.18 6.18 14.07">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 13.18 3.50">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.39 14.07 4.39">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 14.96 5.29">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.39 15.86 6.18">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="5.29 13.18 5.29">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="6.18 14.07 6.18">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="5.29 14.96 3.50">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="6.18 15.86 4.39">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 13.18 13.18">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.39 14.07 14.07">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="3.50 14.96 14.96">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="4.39 15.86 15.86">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="0.76">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform trans

# %%
calc = GPAW(h=0.18, xc='PBE', txt='c.txt')
sys.set_calculator(calc)
sys.get_potential_energy()

elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('c.cube', sys, data=elf_g)

# %% [markdown]
# Defining a bulk metal

# %%
from ase.build import bulk

sys = bulk("Li", "bcc", a=3.51, cubic=True)
sys *= (4, 4, 4)
HTML(atoms_to_html(sys))
# Out:
# <html>
#  <head>
#   <title>ASE atomic visualization</title>
#   <link rel="stylesheet" type="text/css"
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#   </link>
#   <script type="text/javascript"
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#   </script>
#  </head>
#  <body>
#   <X3D style="margin:0; padding:0; width:100%; height:100%; border:none;">
#    <Scene>
#     <Transform translation="0.00 0.00 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 1.75 1.75">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 0.00 3.51">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 1.75 5.26">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 0.00 7.02">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 1.75 8.77">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 0.00 10.53">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 1.75 12.29">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 3.51 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 5.26 1.75">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 3.51 3.51">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 5.26 5.26">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 3.51 7.02">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 5.26 8.77">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 3.51 10.53">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 5.26 12.29">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 7.02 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 8.77 1.75">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 7.02 3.51">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 8.77 5.26">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 7.02 7.02">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 8.77 8.77">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 7.02 10.53">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 8.77 12.29">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 10.53 0.00">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 12.29 1.75">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 10.53 3.51">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="1.75 12.29 5.26">
#      <Shape>
#       <Appearance>
#        <Material diffuseColor="0.800 0.502 1.000" specularColor="0.5 0.5 0.5">
#        </Material>
#       </Appearance>
#       <Sphere radius="1.28">
#       </Sphere>
#      </Shape>
#     </Transform>
#     <Transform translation="0.00 1

# %%
calc = GPAW(h=0.18, xc='PBE', txt='li.txt')
sys.set_calculator(calc)
sys.get_potential_energy()

elf = ELF(calc)
elf.initialize(calc)
elf.update()
elf_g = elf.get_electronic_localization_function(gridrefinement=2)
write('li.cube', sys, data=elf_g)
